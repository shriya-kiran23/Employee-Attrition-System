# %% [markdown]
# <a href="https://colab.research.google.com/github/shriya-kiran23/Employee-Attrition-System/blob/main/Employee_Attrition_rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#                         _id   Age Attrition     BusinessTravel  DailyRate  \
# 0  681cd01b2f568b9bd7d634c0  41.0       Yes      Travel_Rarely     1102.0
# 1  681cd01b2f568b9bd7d634c1  49.0        No  Travel_Frequently      279.0
# 2  681cd01b2f568b9bd7d634c2  37.0       Yes      Travel_Rarely     1373.0
# 3  681cd01b2f568b9bd7d634c3  33.0        No  Travel_Frequently     1392.0
# 4  681cd01b2f568b9bd7d634c4  27.0        No      Travel_Rarely      591.0
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales               1.0        2.0  Life Sciences
# 1  Research & Development               8.0        1.0  Life Sciences
# 2  Research & Development               2.0        2.0          Other
# 3  Research & Development               3.0        4.0  Life Sciences
# 4  Research & Development               2.0        1.0        Medical
#
#    EmployeeCount  ...  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
data.head()
# Out:
#                         _id   Age Attrition     BusinessTravel  DailyRate  \
# 0  681cd01b2f568b9bd7d634c0  41.0       Yes      Travel_Rarely     1102.0
# 1  681cd01b2f568b9bd7d634c1  49.0        No  Travel_Frequently      279.0
# 2  681cd01b2f568b9bd7d634c2  37.0       Yes      Travel_Rarely     1373.0
# 3  681cd01b2f568b9bd7d634c3  33.0        No  Travel_Frequently     1392.0
# 4  681cd01b2f568b9bd7d634c4  27.0        No      Travel_Rarely      591.0
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales               1.0        2.0  Life Sciences
# 1  Research & Development               8.0        1.0  Life Sciences
# 2  Research & Development               2.0        2.0          Other
# 3  Research & Development               3.0        4.0  Life Sciences
# 4  Research & Development               2.0        1.0        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _id                       1471 non-null   object
#  1   Age                       1470 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   float64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   float64
#  7   Education                 1470 non-null   float64
#  8   EducationField            1470 non-null   object
#  9   EmployeeCount             1470 non-null   float64
#  10  EmployeeNumber            1470 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   float64
#  12  Gender                    1470 non-null   object
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# **Observations**
# 1.we have only int and string data types features.there is no feature with float.26 features are numerical an 9 features are categorical.
# 2.attrition is out target value which has no missing value.But,the quality of data of emp having attrition is less compared to employees which doesnot have attrition
#
# this data set is a good fit for this project as there is no any missing values in dataset

# %% [markdown]
# ### Check duplicates

# %%
print(data.duplicated().value_counts())
data.drop_duplicates(inplace = True)
print(len(data))
# Out:
# False    1470
# Name: count, dtype: int64
# 1470

# %% [markdown]
# ### check for missing values

# %%
data.isnull().sum()
# Out:
# _id                         0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %% [markdown]
# ## target variable

# %%
plt.figure(figsize=(15,5))
plt.rc("font",size=14)
sns.countplot(y='Attrition',data=data)
plt.show()

# %% [markdown]
# over here we have noticed  the target column is highly imbalanced,we need to balance the data using statistical Methods

# %% [markdown]
# ## exploratory data analysis

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Department',hue='Attrition', data=data, palette='hot')
plt.title("Attrition w.r.t Department")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='JobRole',hue='Attrition', data=data, palette='hot')
plt.title("JobRole w.r.t Attrition")
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Gender',hue='Attrition', data=data, palette='hot')
plt.title("Gender w.r.t Attrition")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Observations
# 1.emplyees working in R&D dept are more ,but the emplyees in sales dept or at position like sales executives,sales representatives leaves the job early
# 2.males are more under attrition then the females

# %%
data["TotalWorkingYears"].value_counts()
# Out:
# TotalWorkingYears
# 10.0    202
# 6.0     125
# 8.0     103
# 9.0      96
# 5.0      88
# 7.0      81
# 1.0      81
# 4.0      63
# 12.0     48
# 3.0      42
# 15.0     40
# 16.0     37
# 11.0     36
# 13.0     36
# 21.0     34
# 17.0     33
# 14.0     31
# 2.0      31
# 20.0     30
# 18.0     27
# 19.0     22
# 23.0     22
# 22.0     21
# 24.0     18
# 26.0     14
# 25.0     14
# 28.0     14
# 0.0      11
# 29.0     10
# 31.0      9
# 32.0      9
# 30.0      7
# 33.0      7
# 27.0      7
# 36.0      6
# 34.0      5
# 37.0      4
# 35.0      3
# 40.0      2
# 38.0      1
# Name: count, dtype: int64

# %%
labels=data["TotalWorkingYears"].value_counts().index.tolist()
labels

# %%
# distribution of age
plt.figure(figsize=(12,5))
sns.distplot(data['Age'],hist=False)
plt.show()

# %% [markdown]
# age column is very well normalized,most of the employees are age betwween 25 to 40
# we are having some of the numerical columns which are label encoded for us,they are ordinal labels,so lets have a look at them first

# %%
ordinal_features = ['Education','EnvironmentSatisfaction','JobInvolvement','JobSatisfaction',
                    'PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']
data[ordinal_features].head()
# Out:
#    Education  EnvironmentSatisfaction  JobInvolvement  JobSatisfaction  \
# 0        2.0                      2.0             3.0              4.0
# 1        1.0                      3.0             2.0              2.0
# 2        2.0                      4.0             2.0              3.0
# 3        4.0                      4.0             3.0              3.0
# 4        1.0                      1.0             3.0              2.0
#
#    PerformanceRating  RelationshipSatisfaction  WorkLifeBalance
# 0                3.0                       1.0              1.0
# 1                4.0                       4.0              3.0
# 2                3.0                       2.0              3.0
# 3                3.0                       3.0              3.0
# 4                3.0                       4.0              3.0

# %%
edu_map = {1 :'Below College', 2: 'College', 3 :'Bachelor', 4 :'Master', 5: 'Doctor'}
plt.figure(figsize=(12,5))
sns.countplot(x=data['Education'].map(edu_map), hue='Attrition', data=data, palette='hot')
plt.title("Education W.R.T Attrition")
plt.show()

# %% [markdown]
# OBSERVATIONS
#
# Employees from Bachelor are more, then from Masters background. Attrition wrt to bachelor can be seem more because they have more and more expectation from companies and it will be interesting to see the reason behind this in this dataset.

# %%
# Target Variable(Attrition)
data['Attrition'] = data['Attrition'].replace({'No':0,'Yes':1})

# %%
#encode binary variables
data['OverTime'] = data['OverTime'].map({'No':0,'Yes':1})
data['Gender'] = data['Gender'].map({'Male':0,'Female':1})

# %%
# encode categorical columns which are ordinal, use labelEncoding
# apply Label encoder to df_categorical
from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
label_encoders = {}
for column in encoding_cols:
    label_encoders[column] = LabelEncoder()
    data[column] = label_encoders[column].fit_transform(data[column])

# %%
# look at the final data
data.head()

# %% [markdown]
# Machine Learning: Splitting the data into Training and Testing sample
# We dont use the full data for creating the model. Some data is randomly selected and kept aside for checking how good the model is. This is known as Testing Data and the remaining data is called Training data on which the model is built. Typically 70% of data is used as Training data and the rest 30% is used as Tesing data.

# %%
X = data.drop(['Attrition','Over18'], axis=1)
y = data['Attrition'].values

# %% [markdown]
# Resampling
# Resampling is the method that consists of drawing repeated samples from the original data samples. The method of Resampling is a nonparametric method of statistical inference Oversampling and undersampling in data analysis are techniques used to adjust the class distribution of a data set. These terms are used both in statistical sampling, survey design methodology and in machine learning. Oversampling and undersampling are opposite and roughly equivalent techniques
#
# We are going to use Over Sampling.
# We will not use Under Sampling to avoid data loss.

# %%
import numpy as np
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

# Remove NaN entries
mask = ~np.isnan(y)
X_clean = X[mask]
y_clean = y[mask]

print(Counter(y_clean))

rus = RandomOverSampler(random_state=42)
X_over, y_over = rus.fit_resample(X_clean, y_clean)

print(Counter(y_over))
# Out:
# Counter({np.float64(0.0): 1233, np.float64(1.0): 237})
# Counter({np.float64(1.0): 1233, np.float64(0.0): 1233})

# %%
# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size=0.2, random_state=42)

# %%
# Sanity check for the sampled data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1972, 37)
# (1972,)
# (494, 37)
# (494,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score

# %%
import pandas as pd

# Check for non-numeric columns
non_numeric = X_train.select_dtypes(exclude=['number']).columns
print("Non-numeric columns:", non_numeric)

# Drop them or convert appropriately
X_train_clean = X_train.drop(columns=non_numeric)
X_test_clean = X_test.drop(columns=non_numeric)  # Assuming you’ll use it later too

# Now fit the model
logreg = LogisticRegression()
logreg.fit(X_train_clean, y_train)
# Out:
# Non-numeric columns: Index(['_id', 'name', 'attrition', 'job_role'], dtype='object')
# LogisticRegression()

# %%
# Drop the same columns from X_test that were removed from X_train
X_test_clean = X_test[X_train_clean.columns]

# Now make predictions
prediction = logreg.predict(X_test_clean)
cnf_matrix = confusion_matrix(y_test, prediction)
print("Accuracy Score -", accuracy_score(y_test, prediction))
# Out:
# Accuracy Score - 0.6417004048582996

# %%
# Make sure X_test_clean is aligned with X_train_clean
X_test_clean = X_test[X_train_clean.columns]

# Now your plotting code will work correctly
fig = plt.figure(figsize=(15,6))

# Confusion matrix heatmap
ax1 = fig.add_subplot(1,2,1)
ax1 = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap='Blues', fmt='d')
bottom, top = ax1.get_ylim()
ax1.set_ylim(bottom + 0.5, top - 0.5)
plt.xlabel('Predicted')
plt.ylabel('Expected')

# ROC curve
ax2 = fig.add_subplot(1,2,2)
y_pred_proba = logreg.predict_proba(X_test_clean)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
ax2.plot(fpr, tpr, label="AUC = {:.2f}".format(auc))
ax2.legend(loc=4)
plt.show()

# %%
pip install pymongo

# %%
from pymongo import MongoClient
import pandas as pd


# Replace with your actual credentials
uri = "mongodb+srv://shriyakiran23:12345@project.klxhfs6.mongodb.net/"

# Create client
client = MongoClient(uri)

# Access your database
db = client['Employee']

# Access your collection
collection = db['Details']

# Test: Print documents
for doc in collection.find().limit(5):
    print(doc)

data = pd.DataFrame(list(collection.find()))
# Out:
# {'_id': ObjectId('681cd01b2f568b9bd7d634c0'), 'Age': 41, 'Attrition': 'Yes', 'BusinessTravel': 'Travel_Rarely', 'DailyRate': 1102, 'Department': 'Sales', 'DistanceFromHome': 1, 'Education': 2, 'EducationField': 'Life Sciences', 'EmployeeCount': 1, 'EmployeeNumber': 1, 'EnvironmentSatisfaction': 2, 'Gender': 'Female', 'HourlyRate': 94, 'JobInvolvement': 3, 'JobLevel': 2, 'JobRole': 'Sales Executive', 'JobSatisfaction': 4, 'MaritalStatus': 'Single', 'MonthlyIncome': 5993, 'MonthlyRate': 19479, 'NumCompaniesWorked': 8, 'Over18': 'Y', 'OverTime': 'Yes', 'PercentSalaryHike': 11, 'PerformanceRating': 3, 'RelationshipSatisfaction': 1, 'StandardHours': 80, 'StockOptionLevel': 0, 'TotalWorkingYears': 8, 'TrainingTimesLastYear': 0, 'WorkLifeBalance': 1, 'YearsAtCompany': 6, 'YearsInCurrentRole': 4, 'YearsSinceLastPromotion': 0, 'YearsWithCurrManager': 5}
# ...
